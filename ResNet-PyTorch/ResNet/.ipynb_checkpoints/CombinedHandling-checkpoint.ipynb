# %%
import os
import torch
import scipy.io
import torch.nn as nn  # Import nn module
import torch.optim as optim  # Import optim module
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import matplotlib.pyplot as plt

from combined import CombinedModel

# Check for CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Define the transformations
transform = transforms.Compose([
    transforms.Normalize(mean=[0.5] * 31, std=[0.5] * 31)  # Normalize each channel with mean 0.5 and std 0.5
])

class HyperspectralDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.data = []
        self.labels = []
        self.label_map = {}
        self.transform = transform

        species_dirs = os.listdir(root_dir)
        for idx, species in enumerate(species_dirs):
            species_dir = os.path.join(root_dir, species)
            if os.path.isdir(species_dir):
                self.label_map[species] = idx
                mat_files = [f for f in os.listdir(species_dir) if f.endswith('.mat')]
                for mat_file in mat_files:
                    file_path = os.path.join(species_dir, mat_file)
                    self.data.append(file_path)
                    self.labels.append(idx)
        
        print("Label mapping:", self.label_map)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        mat_file = self.data[idx]
        label = self.labels[idx]

        # Load .mat file
        mat_contents = scipy.io.loadmat(mat_file)
        cube = mat_contents['cube']
        profile = mat_contents['profile']

        # Convert to PyTorch tensor and permute dimensions
        cube = torch.tensor(cube, dtype=torch.float32).permute(2, 0, 1)
        profile = torch.tensor(profile, dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.long)

        if self.transform:
            cube = self.transform(cube)

        return cube, profile, label

    def get_image_path(self, idx):
        return self.data[idx]

# %%
# Function to get all file paths from a dataset
def get_all_file_paths(dataset):
    file_paths = []
    for idx in range(len(dataset)):
        file_paths.append(dataset.get_image_path(idx))
    return file_paths

# # Initialize the dataset with transformations
dataset = HyperspectralDataset(root_dir='../../resizedstuff/mst_resized_all', transform=transform)



train_dataset = HyperspectralDataset(root_dir='../../resizedstuff/mst_resized_train', transform=transform)
test_dataset = HyperspectralDataset(root_dir='../../resizedstuff/mst_resized_test', transform=transform)
val_dataset = HyperspectralDataset(root_dir='../../resizedstuff/mst_resized_validation', transform=transform)


# Create DataLoaders for training, validation, and test sets
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, num_workers=4)
# Out:
# Label mapping: {'Acinetobacter_baumanii': 0, 'Lactobacillus_casei': 1, 'Lactobacillus_jehnsenii': 2, 'Lactobacillus_gasseri': 3, 'Lactobacillus_delbrueckii': 4, 'Lactobacillus_salivarius': 5, 'Propionibacterium_acnes': 6, 'Lactobacillus_paracasei': 7, 'Bifidobacterium_spp': 8, 'Lactobacillus_reuteri': 9, 'Staphylococcus_aureus': 10, 'Escherichia_coli': 11, 'Lactobacillus_rhamnosus': 12, 'Lactobacillus_plantarum': 13, 'Enterococcus_faecium': 14, 'Porfyromonas_gingivalis': 15, 'Enterococcus_faecalis': 16, 'Micrococcus_spp': 17, 'Fusobacterium': 18, 'Actinomyces_israeli': 19, 'Lactobacillus_crispatus': 20, 'Clostridium_perfringens': 21, 'Staphylococcus_epidermidis': 22, 'Listeria_monocytogenes': 23, 'Pseudomonas_aeruginosa': 24, 'Lactobacillus_johnsonii': 25, 'Streptococcus_agalactiae': 26, 'Staphylococcus_saprophiticus': 27, 'Bacteroides_fragilis': 28, 'Neisseria_gonorrhoeae': 29, 'Veionella': 30, 'Proteus': 31, 'Candida_albicans': 32}
# Label mapping: {'Acinetobacter_baumanii': 0, 'Lactobacillus_casei': 1, 'Lactobacillus_jehnsenii': 2, 'Lactobacillus_gasseri': 3, 'Lactobacillus_delbrueckii': 4, 'Lactobacillus_salivarius': 5, 'Propionibacterium_acnes': 6, 'Lactobacillus_paracasei': 7, 'Bifidobacterium_spp': 8, 'Lactobacillus_reuteri': 9, 'Staphylococcus_aureus': 10, 'Escherichia_coli': 11, 'Lactobacillus_rhamnosus': 12, 'Lactobacillus_plantarum': 13, 'Enterococcus_faecium': 14, 'Porfyromonas_gingivalis': 15, 'Enterococcus_faecalis': 16, 'Micrococcus_spp': 17, 'Fusobacterium': 18, 'Actinomyces_israeli': 19, 'Lactobacillus_crispatus': 20, 'Clostridium_perfringens': 21, 'Staphylococcus_epidermidis': 22, 'Listeria_monocytogenes': 23, 'Pseudomonas_aeruginosa': 24, 'Lactobacillus_johnsonii': 25, 'Streptococcus_agalactiae': 26, 'Staphylococcus_saprophiticus': 27, 'Bacteroides_fragilis': 28, 'Neisseria_gonorrhoeae': 29, 'Veionella': 30, 'Proteus': 31, 'Candida_albicans': 32}
# Label mapping: {'Acinetobacter_baumanii': 0, 'Lactobacillus_casei': 1, 'Lactobacillus_jehnsenii': 2, 'Lactobacillus_gasseri': 3, 'Lactobacillus_delbrueckii': 4, 'Lactobacillus_salivarius': 5, 'Propionibacterium_acnes': 6, 'Lactobacillus_paracasei': 7, 'Bifidobacterium_spp': 8, 'Lactobacillus_reuteri': 9, 'Staphylococcus_aureus': 10, 'Escherichia_coli': 11, 'Lactobacillus_rhamnosus': 12, 'Lactobacillus_plantarum': 13, 'Enterococcus_faecium': 14, 'Porfyromonas_gingivalis': 15, 'Enterococcus_faecalis': 16, 'Micrococcus_spp': 17, 'Fusobacterium': 18, 'Actinomyces_israeli': 19, 'Lactobacillus_crispatus': 20, 'Clostridium_perfringens': 21, 'Staphylococcus_epidermidis': 22, 'Listeria_monocytogenes': 23, 'Pseudomonas_aeruginosa': 24, 'Lactobacillus_johnsonii': 25, 'Streptococcus_agalactiae': 26, 'Staphylococcus_saprophiticus': 27, 'Bacteroides_fragilis': 28, 'Neisseria_gonorrhoeae': 29, 'Veionella': 30, 'Proteus': 31, 'Candida_albicans': 32}
# Label mapping: {'Acinetobacter_baumanii': 0, 'Lactobacillus_casei': 1, 'Lactobacillus_jehnsenii': 2, 'Lactobacillus_gasseri': 3, 'Lactobacillus_delbrueckii': 4, 'Lactobacillus_salivarius': 5, 'Propionibacterium_acnes': 6, 'Lactobacillus_paracasei': 7, 'Bifidobacterium_spp': 8, 'Lactobacillus_reuteri': 9, 'Staphylococcus_aureus': 10, 'Escherichia_coli': 11, 'Lactobacillus_rhamnosus': 12, 'Lactobacillus_plantarum': 13, 'Enterococcus_faecium': 14, 'Porfyromonas_gingivalis': 15, 'Enterococcus_faecalis': 16, 'Micrococcus_spp': 17, 'Fusobacterium': 18, 'Actinomyces_israeli': 19, 'Lactobacillus_crispatus': 20, 'Clostridium_perfringens': 21, 'Staphylococcus_epidermidis': 22, 'Listeria_monocytogenes': 23, 'Pseudomonas_aeruginosa': 24, 'Lactobacillus_johnsonii': 25, 'Streptococcus_agalactiae': 26, 'Staphylococcus_saprophiticus': 27, 'Bacteroides_fragilis': 28, 'Neisseria_gonorrhoeae': 29, 'Veionella': 30, 'Proteus': 31, 'Candida_albicans': 32}

# %%
model = CombinedModel(num_classes=len(dataset.label_map)).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0005)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=5)

# %%
# Function to check gradients
def check_gradients(model):
    for name, param in model.named_parameters():
        if param.grad is not None:
            print(f'{name} gradient: {param.grad.abs().mean().item()}')
            
check_gradients(model)

# %%
# Initialize lists to store the metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
lr_change_epochs = []

# Number of epochs
num_epochs = 200

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for cube, profile, label in train_loader:
        cube, profile, label = cube.to(device), profile.to(device), label.to(device)
        
        optimizer.zero_grad()
        output = model(cube, profile)
        loss = criterion(output, label)
        loss.backward()
        
        # Check gradients
       # check_gradients(model)
        
        optimizer.step()

        running_loss += loss.item()
        
        _, predicted = torch.max(output.data, 1)
        total_train += label.size(0)
        correct_train += (predicted == label).sum().item()

    avg_loss = running_loss / len(train_loader)
    train_losses.append(avg_loss)
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Validation phase
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for cube, profile, label in val_loader:
            cube, profile, label = cube.to(device), profile.to(device), label.to(device)

            output = model(cube, profile)
            loss = criterion(output, label)
            val_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total_val += label.size(0)
            correct_val += (predicted == label).sum().item()

    avg_val_loss = val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    val_accuracy = 100 * correct_val / total_val
    val_accuracies.append(val_accuracy)
    print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    # Step the scheduler based on validation loss and track LR changes
    old_lr = optimizer.param_groups[0]['lr']
    scheduler.step(avg_val_loss)
    new_lr = optimizer.param_groups[0]['lr']
    if new_lr != old_lr:
        lr_change_epochs.append(epoch)
        print(f"Learning rate reduced from {old_lr} to {new_lr}")
# Out:
# Epoch [1/200], Loss: 5.1781, Training Accuracy: 22.01%
# Validation Loss: 4.9074, Validation Accuracy: 52.63%
# Epoch [2/200], Loss: 3.9898, Training Accuracy: 39.74%
# Validation Loss: 2.1915, Validation Accuracy: 67.11%
# Epoch [3/200], Loss: 3.1401, Training Accuracy: 54.48%
# Validation Loss: 2.3987, Validation Accuracy: 72.37%
# Epoch [4/200], Loss: 2.9221, Training Accuracy: 54.10%
# Validation Loss: 2.0355, Validation Accuracy: 77.63%
# Epoch [5/200], Loss: 2.7790, Training Accuracy: 57.84%
# Validation Loss: 0.9703, Validation Accuracy: 77.63%
# Epoch [6/200], Loss: 2.3128, Training Accuracy: 64.55%
# Validation Loss: 1.5713, Validation Accuracy: 80.26%
# Epoch [7/200], Loss: 2.0829, Training Accuracy: 65.67%
# Validation Loss: 1.8141, Validation Accuracy: 73.68%
# Epoch [8/200], Loss: 2.0407, Training Accuracy: 66.23%
# Validation Loss: 1.3656, Validation Accuracy: 85.53%
# Epoch [9/200], Loss: 1.6736, Training Accuracy: 72.39%
# Validation Loss: 1.4882, Validation Accuracy: 77.63%
# Epoch [10/200], Loss: 1.8988, Training Accuracy: 70.34%
# Validation Loss: 1.7985, Validation Accuracy: 78.95%
# Epoch [11/200], Loss: 1.8211, Training Accuracy: 70.52%
# Validation Loss: 0.9393, Validation Accuracy: 84.21%
# Epoch [12/200], Loss: 1.4452, Training Accuracy: 74.81%
# Validation Loss: 1.3481, Validation Accuracy: 85.53%
# Epoch [13/200], Loss: 1.7139, Training Accuracy: 72.76%
# Validation Loss: 1.7986, Validation Accuracy: 78.95%
# Epoch [14/200], Loss: 1.8961, Training Accuracy: 74.07%
# Validation Loss: 1.7912, Validation Accuracy: 78.95%
# Epoch [15/200], Loss: 1.5564, Training Accuracy: 74.63%
# Validation Loss: 1.7732, Validation Accuracy: 85.53%
# Epoch [16/200], Loss: 1.6247, Training Accuracy: 73.51%
# Validation Loss: 1.5149, Validation Accuracy: 82.89%
# Epoch [17/200], Loss: 1.4380, Training Accuracy: 78.17%
# Validation Loss: 0.9699, Validation Accuracy: 86.84%
# Learning rate reduced from 0.01 to 0.005
# Epoch [18/200], Loss: 0.8089, Training Accuracy: 83.58%
# Validation Loss: 1.1862, Validation Accuracy: 85.53%
# Epoch [19/200], Loss: 0.6943, Training Accuracy: 84.14%
# Validation Loss: 0.9393, Validation Accuracy: 90.79%
# Epoch [20/200], Loss: 0.5998, Training Accuracy: 86.01%
# Validation Loss: 0.7182, Validation Accuracy: 89.47%
# Epoch [21/200], Loss: 0.7794, Training Accuracy: 85.07%
# Validation Loss: 0.9559, Validation Accuracy: 86.84%
# Epoch [22/200], Loss: 0.6933, Training Accuracy: 85.26%
# Validation Loss: 0.6063, Validation Accuracy: 89.47%
# Epoch [23/200], Loss: 0.7196, Training Accuracy: 83.77%
# Validation Loss: 0.9869, Validation Accuracy: 86.84%
# Epoch [24/200], Loss: 0.7445, Training Accuracy: 83.02%
# Validation Loss: 0.8749, Validation Accuracy: 88.16%
# Epoch [25/200], Loss: 0.5894, Training Accuracy: 86.94%
# Validation Loss: 0.8040, Validation Accuracy: 89.47%
# Epoch [26/200], Loss: 0.6016, Training Accuracy: 85.63%
# Validation Loss: 0.5131, Validation Accuracy: 89.47%
# Epoch [27/200], Loss: 0.5793, Training Accuracy: 86.94%
# Validation Loss: 0.8863, Validation Accuracy: 89.47%
# Epoch [28/200], Loss: 0.6575, Training Accuracy: 84.70%
# Validation Loss: 0.7913, Validation Accuracy: 86.84%
# Epoch [29/200], Loss: 0.4552, Training Accuracy: 87.50%
# Validation Loss: 0.8578, Validation Accuracy: 85.53%
# Epoch [30/200], Loss: 0.4893, Training Accuracy: 86.38%
# Validation Loss: 0.6688, Validation Accuracy: 89.47%
# Epoch [31/200], Loss: 0.4711, Training Accuracy: 88.62%
# Validation Loss: 1.0383, Validation Accuracy: 86.84%
# Epoch [32/200], Loss: 0.5433, Training Accuracy: 86.57%
# Validation Loss: 0.9884, Validation Accuracy: 88.16%
# Learning rate reduced from 0.005 to 0.0025
# Epoch [33/200], Loss: 0.4293, Training Accuracy: 89.74%
# Validation Loss: 0.5821, Validation Accuracy: 89.47%
# Epoch [34/200], Loss: 0.3695, Training Accuracy: 90.86%
# Validation Loss: 0.5869, Validation Accuracy: 89.47%
# Epoch [35/200], Loss: 0.2792, Training Accuracy: 90.86%
# Validation Loss: 0.6670, Validation Accuracy: 89.47%
# Epoch [36/200], Loss: 0.3177, Training Accuracy: 90.49%
# Validation Loss: 0.6897, Validation Accuracy: 90.79%
# Epoch [37/200], Loss: 0.3844, Training Accuracy: 90.30%
# Validation Loss: 0.7902, Validation Accuracy: 88.16%
# Epoch [38/200], Loss: 0.3522, Training Accuracy: 90.86%
# Validation Loss: 0.8674, Validation Accuracy: 84.21%
# Learning rate reduced from 0.0025 to 0.00125
# Epoch [39/200], Loss: 0.2631, Training Accuracy: 92.54%
# Validation Loss: 0.7276, Validation Accuracy: 88.16%
# Epoch [40/200], Loss: 0.2043, Training Accuracy: 92.91%
# Validation Loss: 0.6152, Validation Accuracy: 89.47%
# Epoch [41/200], Loss: 0.2431, Training Accuracy: 93.28%
# Validation Loss: 0.5376, Validation Accuracy: 90.79%
# Epoch [42/200], Loss: 0.2418, Training Accuracy: 93.28%
# Validation Loss: 0.7231, Validation Accuracy: 89.47%
# Epoch [43/200], Loss: 0.2186, Training Accuracy: 93.66%
# Validation Loss: 0.7625, Validation Accuracy: 86.84%
# Epoch [44/200], Loss: 0.2711, Training Accuracy: 92.91%
# Validation Loss: 0.5695, Validation Accuracy: 92.11%
# Learning rate reduced from 0.00125 to 0.000625
# Epoch [45/200], Loss: 0.2593, Training Accuracy: 92.54%
# Validation Loss: 0.6755, Validation Accuracy: 88.16%
# Epoch [46/200], Loss: 0.2314, Training Accuracy: 92.35%
# Validation Loss: 0.7675, Validation Accuracy: 88.16%
# Epoch [47/200], Loss: 0.2607, Training Accuracy: 91.60%
# Validation Loss: 0.7214, Validation Accuracy: 89.47%
# Epoch [48/200], Loss: 0.2901, Training Accuracy: 93.47%
# Validation Loss: 0.8368, Validation Accuracy: 89.47%
# Epoch [49/200], Loss: 0.2456, Training Accuracy: 93.66%
# Validation Loss: 0.7310, Validation Accuracy: 88.16%
# Epoch [50/200], Loss: 0.2614, Training Accuracy: 91.23%
# Validation Loss: 0.9298, Validation Accuracy: 86.84%
# Learning rate reduced from 0.000625 to 0.0003125
# Epoch [51/200], Loss: 0.2832, Training Accuracy: 93.10%
# Validation Loss: 0.9327, Validation Accuracy: 85.53%
# Epoch [52/200], Loss: 0.2110, Training Accuracy: 92.91%
# Validation Loss: 0.6383, Validation Accuracy: 92.11%
# Epoch [53/200], Loss: 0.2756, Training Accuracy: 92.72%
# Validation Loss: 0.6507, Validation Accuracy: 90.79%
# Epoch [54/200], Loss: 0.2032, Training Accuracy: 94.22%
# Validation Loss: 0.7652, Validation Accuracy: 89.47%
# Epoch [55/200], Loss: 0.1907, Training Accuracy: 94.78%
# Validation Loss: 0.7405, Validation Accuracy: 88.16%
# Epoch [56/200], Loss: 0.2055, Training Accuracy: 92.35%
# Validation Loss: 0.6817, Validation Accuracy: 86.84%
# Learning rate reduced from 0.0003125 to 0.00015625
# Epoch [57/200], Loss: 0.1615, Training Accuracy: 95.34%
# Validation Loss: 0.6654, Validation Accuracy: 88.16%
# Epoch [58/200], Loss: 0.2000, Training Accuracy: 94.40%
# Validation Loss: 0.5858, Validation Accuracy: 89.47%
# Epoch [59/200], Loss: 0.2164, Training Accuracy: 94.03%
# Validation Loss: 0.7706, Validation Accuracy: 89.47%
# Epoch [60/200], Loss: 0.2183, Training Accuracy: 91.79%
# Validation Loss: 0.6048, Validation Accuracy: 89.47%
# Epoch [61/200], Loss: 0.1507, Training Accuracy: 94.78%
# Validation Loss: 0.6251, Validation Accuracy: 89.47%
# Epoch [62/200], Loss: 0.1319, Training Accuracy: 95.52%
# Validation Loss: 0.5770, Validation Accuracy: 90.79%
# Learning rate reduced from 0.00015625 to 7.8125e-05
# Epoch [63/200], Loss: 0.1520, Training Accuracy: 95.34%
# Validation Loss: 0.7546, Validation Accuracy: 90.79%
# Epoch [64/200], Loss: 0.2193, Training Accuracy: 94.40%
# Validation Loss: 0.6632, Validation Accuracy: 89.47%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 30
#      25  # Check gradients
#      26 # check_gradients(model)
#      28  optimizer.step()
# ---> 30  running_loss += loss.item()
#      32  _, predicted = torch.max(output.data, 1)
#      33  total_train += label.size(0)
#
# KeyboardInterrupt:

# %%
# Plot the training and validation losses with learning rate change points
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
for lr_epoch in lr_change_epochs:
    plt.axvline(x=lr_epoch, color='r', linestyle='--', label='LR Change' if lr_epoch == lr_change_epochs[0] else "")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Losses with Learning Rate Changes')
plt.show()

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
for lr_epoch in lr_change_epochs:
    plt.axvline(x=lr_epoch, color='r', linestyle='--', label='LR Change' if lr_epoch == lr_change_epochs[0] else "")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Testing phase
model.eval()
test_loss = 0.0
correct_test = 0
total_test = 0
with torch.no_grad():
    for cube, profile, label in test_loader:
        cube, profile, label = cube.to(device), profile.to(device), label.to(device)

        output = model(cube, profile)
        loss = criterion(output, label)
        test_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total_test += label.size(0)
        correct_test += (predicted == label).sum().item()

avg_test_loss = test_loss / len(test_loader)
test_accuracy = 100 * correct_test / total_test
print(f"Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

# %%
# Function to test an individual sample from the test split
def test_individual_test_sample(sample_idx):
    # Load a specific sample from the test dataset
    cube, profile, label = test_dataset[sample_idx]
    
    # Move the sample to GPU if using CUDA
    cube = cube.to(device).unsqueeze(0)  # Add batch dimension
    profile = profile.to(device).unsqueeze(0)  # Add batch dimension
    label = label.to(device)
    
    # Set the model to evaluation mode
    model.eval()
    
    # Disable gradient computation for inference
    with torch.no_grad():
        output = model(cube, profile)
    
    # Apply softmax to get probabilities
    probabilities = torch.nn.functional.softmax(output, dim=1)
    
    # Get the predicted class
    predicted_class = torch.argmax(probabilities, dim=1)
    
    # Print the results
    print(f"Predicted class: {predicted_class.item()}, Probability: {probabilities[0][predicted_class.item()]:.4f}")
    print(f"True label: {label.item()}")

# Test an individual sample from the test split (e.g., sample index 0)
test_individual_test_sample(4)
